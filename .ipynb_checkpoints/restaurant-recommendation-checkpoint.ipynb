# %%
import pandas as pd
from functools import reduce

# %%
accepts = pd.read_csv('./inputs/chefmozaccepts.csv')
cuisine = pd.read_csv('./inputs/chefmozcuisine.csv')
hours = pd.read_csv('./inputs/chefmozhours4.csv')
parking = pd.read_csv('./inputs/chefmozparking.csv')
geoplaces = pd.read_csv('./inputs/geoplaces2.csv')
rating_final = pd.read_csv('./inputs/rating_final.csv')

# %%
accepts.head()
# Out:
#    placeID             Rpayment
# 0   135110                 cash
# 1   135110                 VISA
# 2   135110  MasterCard-Eurocard
# 3   135110     American_Express
# 4   135110     bank_debit_cards

# %%
cuisine.head()
# Out:
#    placeID        Rcuisine
# 0   135110         Spanish
# 1   135109         Italian
# 2   135107  Latin_American
# 3   135106         Mexican
# 4   135105       Fast_Food

# %%
hours.head()
# Out:
#    placeID         hours                  days
# 0   135111  00:00-23:30;  Mon;Tue;Wed;Thu;Fri;
# 1   135111  00:00-23:30;                  Sat;
# 2   135111  00:00-23:30;                  Sun;
# 3   135110  08:00-19:00;  Mon;Tue;Wed;Thu;Fri;
# 4   135110  00:00-00:00;                  Sat;

# %%
parking.head()
# Out:
#    placeID parking_lot
# 0   135111      public
# 1   135110        none
# 2   135109        none
# 3   135108        none
# 4   135107        none

# %%
geoplaces.head()
# Out:
#    placeID   latitude   longitude  \
# 0   134999  18.915421  -99.184871
# 1   132825  22.147392 -100.983092
# 2   135106  22.149709 -100.976093
# 3   132667  23.752697  -99.163359
# 4   132613  23.752903  -99.165076
#
#                                       the_geom_meter  \
# 0  0101000020957F000088568DE356715AC138C0A525FC46...
# 1  0101000020957F00001AD016568C4858C1243261274BA5...
# 2  0101000020957F0000649D6F21634858C119AE9BF528A3...
# 3  0101000020957F00005D67BCDDED8157C1222A2DC8D84D...
# 4  0101000020957F00008EBA2D06DC8157C194E03B7B504E...
#
#                              name                                 address  \
# 0                 Kiku Cuernavaca                              Revolucion
# 1                 puesto de tacos  esquina santos degollado y leon guzman
# 2      El Rinc�n de San Francisco                         Universidad 169
# 3  little pizza Emilio Portes Gil                 calle emilio portes gil
# ...

# %%
rating_final.head()
# Out:
#   userID  placeID  rating  food_rating  service_rating
# 0  U1077   135085       2            2               2
# 1  U1077   135038       2            2               1
# 2  U1077   132825       2            2               2
# 3  U1077   135060       1            2               2
# 4  U1068   135104       1            1               2

# %%
# Step 1: Combine all the data

# %%
# Step 2: Select features we want to use (latitude, longitude, Rcuisine, etc...)

# %%
# Step 3: Create matrix stuff

# %%
# Step 4: Compute similarity

# %%
# Step 5: Get restaurant name from index

# %%
# Step 6: Return list of restaurants based on similarity scores
